# %%
# Latent Semantic Analysis (LSA)
# Latent Dirichlet Allocation

# %%
# Extract topics from the text in an unsupervised manner

# %%
#  Words coming from different topics are allocated to their respective topics based on probability distributions.

# %%
# Themes are generating particular words

# %%
# We generate words from our themes in our mind apply grammar and put then in a  coherent manner

# %%
# Latent variable is the topic responsible for generation of these words.Latent variable is like the topic which is generating words.
